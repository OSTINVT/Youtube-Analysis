# %%
import pandas as pd
import numpy as np
from dateutil import parser
import isodate
  
# Data visualization libraries
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

# Google API
from googleapiclient.discovery import build

# %%
# NLP libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\ostin v
# [nltk_data]     thomas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\ostin v
# [nltk_data]     thomas\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
api_key = 'AIzaSyD****FQhv*****mAT9iY_uVHlK47fcU' 

channel_ids = ['UCX6b17PVsYBQ0ip5gyeme-Q', # CrashCourse
               'UC6107grRI4m0o2-emgoDnAA', # SmarterEveryDay
               'UCAuUUnT6oDeKwE6v1NGQxug', # TED
               'UCZYTClx2T1of7BRZ86-8fow', # SciShow
               'UCC552Sd-3nyi_tk2BudLUzA', # AsapSCIENCE
               'UC4a-Gbdw7vOaccHmFo40b9g', # Khan Academy
               'UC6nSFpj9HTCZ5t-N3Rm3-HA', # Vsauce
               'UCsXVk37bltHxD1rDPwtNM8Q', # Kurzgesagt – In a Nutshell
               'UCpVm7bg6pXKo1Pr6k5kxG9A', # National Geographic
               'UCHnyfMqiRRG1u-2MsSQLbXA', # Veritasium
              ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    """
    Get channel statistics: title, subscriber count, view count, video count, upload playlist
    Params:
    
    youtube: the build object from googleapiclient.discovery
    channels_ids: list of channel IDs
    
    Returns:
    Dataframe containing the channel statistics for all channels in the provided list: title, subscriber count, view count, video count, upload playlist
    
    """
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return pd.DataFrame(all_data)
def get_video_ids(youtube, playlist_id):
    """
    Get list of video IDs of all videos in the given playlist
    Params:
    
    youtube: the build object from googleapiclient.discovery
    playlist_id: playlist ID of the channel
    
    Returns:
    List of video IDs of all videos in the playlist
    
    """
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

def get_video_details(youtube, video_ids):
    """
    Get video statistics of all videos with given IDs
    Params:
    
    youtube: the build object from googleapiclient.discovery
    video_ids: list of video IDs
    
    Returns:
    Dataframe with statistics of videos, i.e.:
        'channelTitle', 'title', 'description', 'tags', 'publishedAt'
        'viewCount', 'likeCount', 'favoriteCount', 'commentCount'
        'duration', 'definition', 'caption'
    """
        
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

def get_comments_in_videos(youtube, video_ids):
    """
    Get top level comments as text from all videos with given IDs (only the first 10 comments due to quote limit of Youtube API)
    Params:
    
    youtube: the build object from googleapiclient.discovery
    video_ids: list of video IDs
    
    Returns:
    Dataframe with video IDs and associated top level comment in text.
    
    """
    all_comments = []
    
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %%
channel_data = get_channel_stats(youtube, channel_ids)

# %%
channel_data
# Out:
#                   channelName subscribers       views totalVideos  \
# 0                 AsapSCIENCE    10500000  1881748384         477
# 1         National Geographic    22400000  5815753833       10299
# 2                         TED    23800000  2641152864        4588
# 3                  Veritasium    14600000  2345543446         383
# 4                Khan Academy     8210000  2106950306        8377
# 5                     SciShow     7820000  1952943890        3564
# 6                      Vsauce    21000000  3675594699         509
# 7             SmarterEveryDay    11400000  1170214278         374
# 8                 CrashCourse    15200000  1906892581        1508
# 9  Kurzgesagt – In a Nutshell    21700000  2577151095         206
#
#                  playlistId
# 0  UUC552Sd-3nyi_tk2BudLUzA
# 1  UUpVm7bg6pXKo1Pr6k5kxG9A
# 2  UUAuUUnT6oDeKwE6v1NGQxug
# 3  UUHnyfMqiRRG1u-2MsSQLbXA
# 4  UU4a-Gbdw7vOaccHmFo40b9g
# 5  UUZYTClx2T1of7BRZ86-8fow
# 6  UU6nSFpj9HTCZ5t-N3Rm3-HA
# 7  UU6107grRI4m0o2-emgoDnAA
# 8  UUX6b17PVsYBQ0ip5gyeme-Q
# 9  UUsXVk37bltHxD1rDPwtNM8Q

# %%
# Convert count columns to numeric columns
numeric_cols = ['subscribers', 'views', 'totalVideos']
channel_data[numeric_cols] = channel_data[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='channelName', y='subscribers', data=channel_data.sort_values('subscribers', ascending=False))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %%
ax = sns.barplot(x='channelName', y='views', data=channel_data.sort_values('views', ascending=False))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %%
# Create a dataframe with video statistics and comments from all channels

video_df = pd.DataFrame()
comments_df = pd.DataFrame()

for c in channel_data['channelName'].unique():
    print("Getting video information from channel: " + c)
    playlist_id = channel_data.loc[channel_data['channelName']== c, 'playlistId'].iloc[0]
    video_ids = get_video_ids(youtube, playlist_id)
    
    # get video data
    video_data = get_video_details(youtube, video_ids)
    # get comment data
    comments_data = get_comments_in_videos(youtube, video_ids)

    # append video data together and comment data toghether
    video_df = video_df.append(video_data, ignore_index=True)
    comments_df = comments_df.append(comments_data, ignore_index=True)
# Out:
# Getting video information from channel: AsapSCIENCE
# Could not get comments for video n7rnaXDeKpg
# C:\Users\ostin v thomas\AppData\Local\Temp\ipykernel_8548\893411185.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# C:\Users\ostin v thomas\AppData\Local\Temp\ipykernel_8548\893411185.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comments_df = comments_df.append(comments_data, ignore_index=True)
# Getting video information from channel: National Geographic
# Could not get comments for video dCWSEL7dRs8
# Could not get comments for video 8QXubl0V_8g
# Could not get comments for video s92rYUrP2Og
# Could not get comments for video zUv1Uaq4Wxk
# Could not get comments for video LnUvKMhooA4
# Could not get comments for video 3_qe9zQ0h_4
# Could not get comments for video ncirYbEG1Nw
# Could not get comments for video U_uSRHedmSs
# Could not get comments for video qFFPcIcAUUs
# Could not get comments for video 89Az3m-qJeU
# Could not get comments for video yI6M8SxvtcY
# Could not get comments for video zRCKS_mbVY8
# Could not get comments for video Uqnpmpj7YD8
# Could not get comments for video Gu0OOMpdvew
# Could not get comments for video p9A-oxUMAy8
# Could not get comments for video f5GXTEe8_hw
# Could not get comments for video L8VjH4iF3Q0
# Could not get comments for video azWRiwAmGRM
# Could not get comments for video wjE7egjpoNU
# Could not get comments for video d4yjrDSvze0
# Could not get comments for video FEeMT3lP4G8
# Could not get comments for video SCAIedFgdY0
# Could not get comments for video JlTGEPP6evo
# Could not get comments for video g_JFNH_PDgo
# Could not get comments for video bLrUQHE6XgU
# Could not get comments for video 2_x8oRSVfCQ
# Could not get comments for video eE8-u-LCWsg
# Could not get comments for video 8wpyS4DkIN0
# Could not get comments for video TriOIvvl2yI
# Could not get comments for video 6nw2cEXqAaw
# Could not get comments for video hWQu279Jcr8
# Could not get comments for video oJAbATJCugs
# Could not get comments for video YzDJc7zZHaA
# Could not get comments for video qyrS7TQnoAo
# C:\Users\ostin v thomas\AppData\Local\Temp\ipykernel_8548\893411185.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# C:\Users\ostin v thomas\AppData\Local\Temp\ipykernel_8548\893411185.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comments_df = comments_df.append(comments_data, ignore_index=True)
# Getting video information from channel: TED
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 6>()
#       7 print("Getting video information from channel: " + c)
#       8 playlist_id = channel_data.loc[channel_data['channelName']== c, 'playlistId'].iloc[0]
# ----> 9 video_ids = get_video_ids(youtube, playlist_id)
#      11 # get video data
#      12 video_data = get_video_details(youtube, video_ids)
#
# Input In [28], in get_video_ids(youtube, playlist_id)
#      29 """
#      30 Get list of video IDs of all videos in the given playlist
#      31 Params:
#    (...)
#      38
#      39 """
#      41 request = youtube.playlistItems().list(
#      42             part='contentDetails',
#      43             playlistId = playlist_id,
#      44             maxResults = 50)
# ---> 45 response = request.execute()
#      47 video_ids = []
#      49 for i in range(len(response['items'])):
#
# File ~\anaconda3\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/playlistItems?part=contentDetails&playlistId=UUAuUUnT6oDeKwE6v1NGQxug&maxResults=50&key=AIzaSyDlx7FQhvkiDFEBbnmAT9iY_uVHlK47fcU&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %%
video_df
# Out:
#           video_id         channelTitle  \
# 0      1RkXYEc4Ttw          AsapSCIENCE
# 1      BxVGLdMR_8A          AsapSCIENCE
# 2      -hwxBBChA2c          AsapSCIENCE
# 3      BjYzP2pjsy0          AsapSCIENCE
# 4      nFhCAedFeCc          AsapSCIENCE
# ...            ...                  ...
# 10772  6nw2cEXqAaw  National Geographic
# 10773  hWQu279Jcr8  National Geographic
# 10774  oJAbATJCugs  National Geographic
# 10775  YzDJc7zZHaA  National Geographic
# 10776  qyrS7TQnoAo  National Geographic
#
#                                                    title  \
# 0                                How to hack a coin toss
# 1      This piece of paper could revolutionize human ...
# 2          The fastest way to reduce stress (in seconds)
# 3                                        No fap is a fib
# 4              What Happens When You Eat Someone's Butt?
# ...                                                  ...
# 10772                Monster Crocs | National Geographic
# 10773         Gabon: The Last Eden | National Geographic
# 10774           Global Warming 101 | National Geographic
# 10775                   Firehouse Mascot | Dog Whisperer
# 10776             Umbanda Religion | National Geographic
#
#                                              description  \
# 0
# 1      Could this simple kirigami paper be a solution...
# 2      Are you breathing wrong? And can breathwork ac...
# 3
# 4      Eating booty is ON THE RISE! The act is more p...
# ...                                                  ...
# 10772  Gigantic crocodiles are measured with laser be...
# 10773  Gabon's elephant trails provide passage for po...
# 10774  Global warming could do more than just melt po...
# 10775  A Dalmation learns his place at the firehouse ...
# 10776  In Brazil, requests to kill a husband, and rem...
#
#                                                     tags  \
# 0                                                   None
# 1      [asapscience, asap science, asapscience youtub...
# 2      [asapscience, asap science, asapscience youtub...
# 3                                                   None
# 4      [asapscience, asap science, asapscience youtub...
# ...                                                  ...
# 10772  [crocodiles, laser, giant, crocodile, national...
# 10773  [Gabon, elephant, poachers, poaching, national...
# 10774  [101, national geographic, nat geo, natgeo, an...
# 10775  [Dog, Whisperer, Cesar, Millan, dalmation, fir...
# 10776  [umbanda, religion, brazil, south, america, ki...
#
#                 publishedAt viewCount likeCount favouriteCount commentCount  \
# 0      2024-01-05T21:45:00Z     90887      4908           None          112
# 1      2023-12-19T17:00:14Z   1744489     70568           None         2963
# 2      2023-12-14T18:00:13Z    305168     18263           None          432
# 3      2023-12-13T17:00:15Z     65322      2712           None          189
# 4      2023-11-30T17:00:40Z    909577     46755           None         3220
# ...                     ...       ...       ...            ...          ...
# 10772  2007-05-18T16:36:30Z    541552      1319           None          160
# 10773  2007-05-18T15:58:37Z    112053       323           None           46
# 10774  2007-05-18T15:23:22Z   5286519     26979           None        18644
# 10775  2007-05-18T15:04:06Z    252266      1081           None          255
# 10776  2007-05-18T12:38:50Z    289888      1070           None          417
#
#       duration definition caption
# 0        PT43S         hd   false
# 1      PT5M35S         hd   false
# 2      PT9M33S         hd   false
# 3        PT29S         hd   false
# 4      PT5M43S         hd   false
# ...        ...        ...     ...
# 10772  PT4M43S         sd   false
# 10773  PT3M23S         sd   false
# 10774   PT3M4S         sd   false
# 10775  PT3M26S         sd   false
# 10776   PT4M7S         sd   false
#
# [10777 rows x 13 columns]

# %%
comments_df
# Out:
#          video_id                                           comments
# 0     1RkXYEc4Ttw  [Wait.. The starting was like my video, But th...
# 1     BxVGLdMR_8A  [What happens when it gets wet?, LOVE THIS, Di...
# 2     -hwxBBChA2c  [i m gonna give you one better , if you can fi...
# 3     BjYzP2pjsy0  [Dumb, I would like to see a video of how your...
# 4     nFhCAedFeCc  [Really people!!! How can you do such a disgus...
# ...           ...                                                ...
# 8609  kmmy63WMCnc  [why is everyone here from 11 years ago hehe, ...
# 8610  qG1mKDQnpH4  [오늘도 잘 듣고 갑니다. 내 마음속의 마크로스, National Geographi...
# 8611  9BPRVUBMK1c  [All that for five grand?! Lol, O yea. I bet u...
# 8612  zWjuA5KNtsQ  [It's hard to feel sorry for them..., what's t...
# 8613  5wpwYqwf4Qc  [Britain is not a great Culture they are savag...
#
# [8614 rows x 2 columns]

# %%
# Write video data to CSV file for future references
video_df.to_csv('video_data_top10_channels.csv')
comments_df.to_csv('comments_data_top10_channels.csv')

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount          True
# likeCount          True
# favouriteCount     True
# commentCount       True
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.publishedAt.sort_values().value_counts()
# Out:
# 2013-12-31T15:00:03Z    7
# 2012-05-15T17:56:21Z    6
# 2014-01-20T15:00:04Z    5
# 2012-05-15T17:56:12Z    5
# 2013-02-12T22:49:48Z    5
#                        ..
# 2013-01-11T14:24:51Z    1
# 2013-01-13T05:00:42Z    1
# 2013-01-13T19:43:05Z    1
# 2013-01-14T05:53:05Z    1
# 2024-01-11T17:01:28Z    1
# Name: publishedAt, Length: 10533, dtype: int64

# %%
cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[cols] = video_df[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
# Create publish day (in the week) column
video_df['publishedAt'] =  video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
# convert duration to seconds
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
# Add number of tags
video_df['tagsCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
# Comments and likes per 1000 view ratio
video_df['likeRatio'] = video_df['likeCount']/ video_df['viewCount'] * 1000
video_df['commentRatio'] = video_df['commentCount']/ video_df['viewCount'] * 1000

# %%
# Title character length
video_df['titleLength'] = video_df['title'].apply(lambda x: len(x))

# %%
video_df.head()
# Out:
#       video_id channelTitle  \
# 0  1RkXYEc4Ttw  AsapSCIENCE
# 1  BxVGLdMR_8A  AsapSCIENCE
# 2  -hwxBBChA2c  AsapSCIENCE
# 3  BjYzP2pjsy0  AsapSCIENCE
# 4  nFhCAedFeCc  AsapSCIENCE
#
#                                                title  \
# 0                            How to hack a coin toss
# 1  This piece of paper could revolutionize human ...
# 2      The fastest way to reduce stress (in seconds)
# 3                                    No fap is a fib
# 4          What Happens When You Eat Someone's Butt?
#
#                                          description  \
# 0
# 1  Could this simple kirigami paper be a solution...
# 2  Are you breathing wrong? And can breathwork ac...
# 3
# 4  Eating booty is ON THE RISE! The act is more p...
#
#                                                 tags  \
# 0                                               None
# 1  [asapscience, asap science, asapscience youtub...
# 2  [asapscience, asap science, asapscience youtub...
# 3                                               None
# 4  [asapscience, asap science, asapscience youtub...
#
#                 publishedAt  viewCount  likeCount  favouriteCount  \
# 0 2024-01-05 21:45:00+00:00    90887.0     4908.0             NaN
# 1 2023-12-19 17:00:14+00:00  1744489.0    70568.0             NaN
# 2 2023-12-14 18:00:13+00:00   305168.0    18263.0             NaN
# 3 2023-12-13 17:00:15+00:00    65322.0     2712.0             NaN
# 4 2023-11-30 17:00:40+00:00   909577.0    46755.0             NaN
#
#    commentCount duration definition caption pushblishDayName  durationSecs  \
# 0         112.0    PT43S         hd   false           Friday          43.0
# 1        2963.0  PT5M35S         hd   false          Tuesday         335.0
# 2         432.0  PT9M33S         hd   false         Thursday         573.0
# 3         189.0    PT29S         hd   false        Wednesday          29.0
# 4        3220.0  PT5M43S         hd   false         Thursday         343.0
#
#    tagsCount  likeRatio  commentRatio  titleLength
# 0          0  54.001122      1.232299           23
# 1          7  40.451960      1.698492           51
# 2          7  59.845724      1.415614           45
# 3          0  41.517406      2.893359           15
# 4         17  51.403015      3.540107           41

# %%
plt.rcParams['figure.figsize'] = (18, 6)
sns.violinplot(video_df['channelTitle'], video_df['viewCount'], palette = 'pastel')
plt.title('Views per channel', fontsize = 14)
plt.show()
# Out:
# C:\Users\ostin v thomas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "commentCount", y = "viewCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "likeCount", y = "viewCount", ax=ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "commentRatio", y = "viewCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "likeRatio", y = "viewCount", ax=ax[1])
# Out:
# <AxesSubplot:xlabel='likeRatio', ylabel='viewCount'>

# %%
sns.histplot(data=video_df[video_df['durationSecs'] < 10000], x="durationSecs", bins=30)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "durationSecs", y = "commentCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "durationSecs", y = "likeCount", ax=ax[1])
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='likeCount'>

# %%
sns.scatterplot(data = video_df, x = "titleLength", y = "viewCount")
# Out:
# <AxesSubplot:xlabel='titleLength', ylabel='viewCount'>

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words)

# %%
def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %%
sns.scatterplot(data = video_df, x = "tagsCount", y = "viewCount")
# Out:
# <AxesSubplot:xlabel='tagsCount', ylabel='viewCount'>

# %%
day_df = pd.DataFrame(video_df['pushblishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=0)

# %%
stop_words = set(stopwords.words('english'))
comments_df['comments_no_stopwords'] = comments_df['comments'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in comments_df['comments_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words)

# %%
wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)
